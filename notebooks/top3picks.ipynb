# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('../american_soccer_analysis_mls_xpass_players_2020-08-02.csv')  #reading in salary data from american soccer analysis

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 536 entries, 0 to 535
# Data columns (total 12 columns):
#  #   Column                                                                                                      Non-Null Count  Dtype
# ---  ------                                                                                                      --------------  -----
#  0   Player                                                                                                      536 non-null    object
#  1   Team                                                                                                        536 non-null    object
#  2   Season                                                                                                      536 non-null    int64
#  3   MinutesIncludes stoppage time.                                                                              536 non-null    int64
# ...

# %%
df.describe()
# Out:
#        Season  MinutesIncludes stoppage time.      Passes  \
# count   536.0                      536.000000  536.000000
# mean   2020.0                      304.578358   37.927239
# std       0.0                      207.395864   48.662027
# min    2020.0                        2.000000    0.000000
# 25%    2020.0                      117.750000    4.000000
# 50%    2020.0                      275.500000   17.000000
# 75%    2020.0                      490.250000   54.250000
# max    2020.0                      711.000000  249.000000
#
#        Pass %Pass Completion  xPass %Expected pass completion percentage.  \
# count             536.000000                                   536.000000
# mean                0.680806                                     0.715594
# std                 0.287072                                     0.242295
# min                 0.000000                                     0.000000
# ...

# %%
df['Passes'].hist()

# %% [markdown]
# ## Player List from salaries notebook
#
# 1. Jack Elliot
# 2. Aboubacar Keita
# 3. Jonathon Mensah
# 4. Josh Williams
# 5. Nick Lima
# 6. Gabriel Somi
# 7. Erik Godoy
# 8. Ike Opara
# 9. Kai Wagner
# 10. Harold Cummings
# 11. Michael Boxall
# 12. Justen Glad
# 13. Doneil Henry
# 14. Julio Cascante
# 15. Miles Robinson
# 16. Alex De John
# 17. Brent Kallman

# %%
player_lst = ['Jack Elliott', 'Aboubacar Keita', 'Josh Williams', 'Nick Lima', 'Erik Godoy', 
              'Ike Opara', 'Kai Wagner', 'Harold Cummings', 'Michael Boxall', 'Justen Glad', 'Doneil Henry', 'Julio Cascante', 
              'Miles Robinson', 'Alex De John', 'Brent Kallman']

# %%
df[df['Player'].isin(player_lst)]
# Out:
#               Player Team  Season  MinutesIncludes stoppage time.  Passes  \
# 24   Aboubacar Keita  CLB    2020                             380      96
# 27        Kai Wagner  PHI    2020                             502      65
# 30         Ike Opara  MIN    2020                             196      33
# 65    Michael Boxall  MIN    2020                             696      89
# 73    Miles Robinson  ATL    2020                             316      95
# 152      Justen Glad  RSL    2020                             448     112
# 275     Jack Elliott  PHI    2020                             421      79
# 423    Josh Williams  CLB    2020                             105      26
# 507        Nick Lima  SJE    2020                             568      63
#
#      Pass %Pass Completion  xPass %Expected pass completion percentage.  \
# 24                  0.8854                                       0.8464
# 27                  0.7538                                       0.7010
# ...

# %% [markdown]
# ## 1. Brent Kallman
#
# * From Nebraska
# * 6'2" 190 29 years old
# * Currently plays for Minnesota

# %% [markdown]
# ## 2. Ike Opara
#
# * From North Carolina
# * 6'2" 180, 31 years old
# * Currently plays for Minnesota
# * 2019 names to MLS Best XI

# %% [markdown]
# ## 3. Josh Williams
#
# * From Ohio
# * 6'1" 160 23 years old
# * Plays for Columbus Crew
# * Lots of veteran experience
